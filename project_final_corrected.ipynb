# %%
import tensorflow as tf
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
import medmnist
from PIL import Image
from medmnist import INFO, Evaluator
from tensorflow.keras.utils import plot_model
from clearml import Task, OutputModel, Logger
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.callbacks import Callback, ModelCheckpoint
import seaborn as sns
from sklearn.preprocessing import label_binarize

# %% [markdown]
# ## Dataset Preparation and Visualization

# %%
# BloodMNIST dataset information
data_flag = 'bloodmnist'
info = INFO[data_flag]
n_channels = info['n_channels']
classes = info['label']
n_classes = len(info['label'])
DataClass = getattr(medmnist, info['python_class'])

cml_labels = {classes[str(i)]: i for i in range(n_classes)}
print(info)

# Normalize data and class convertiong into one-hot encoded label
def preprocess(image, label):
    image = tf.cast(image, tf.float32) / 255.0  # Normalize pixel values ranging from 0 to 255 to 0 and 1
    image = (image - 0.5) / 0.5  # Normalize to [-1, 1] and centered around 0
    label = tf.one_hot(label, n_classes) #One-hot encoding transforms the integer class label into a binary vector of length n_classes
    return image, label

#load data
train_dataset = DataClass(split='train', transform=None, download=True)
val_dataset = DataClass(split='val', transform=None, download=True)
test_dataset = DataClass(split='test', transform=None, download=True)

print(f'Train samples: {len(train_dataset)}, Validation samples: {len(val_dataset)}, Test samples: {len(test_dataset)}')

# count the number of samples in each class
count = []
for i in range(n_classes):
    count.append((train_dataset.labels == i).sum())
    print(f'{classes[str(i)]}: {count[i]}')

def dataset_to_tf(data, batch_size):
    images = []
    labels = []
    for img, lbl in data:
        images.append(np.array(img))
        labels.append(lbl[0])  # Convert to a scalar
    images = np.stack(images)
    labels = np.array(labels)
    dataset = tf.data.Dataset.from_tensor_slices((images, labels))
    dataset = dataset.map(preprocess)
    return dataset.shuffle(buffer_size=10000).batch(batch_size).prefetch(tf.data.AUTOTUNE)

    
batch_size = 2048
sample_size = 16

train_loader = dataset_to_tf(train_dataset, batch_size)
val_loader = dataset_to_tf(val_dataset, batch_size)
test_loader = dataset_to_tf(test_dataset, batch_size)

# Show some random training images
images, labels = next(iter(train_loader))
plt.figure()
for i in range(sample_size):
    fig = plt.subplot(4, 4, i + 1)
    plt.imshow((images[i].numpy() * 0.5 + 0.5).squeeze(), cmap='gray')
    plt.axis('off')
    plt.title(f'GT: {classes[str(tf.argmax(labels[i]).numpy())][:21]}')
    
plt.subplots_adjust(right=1.5, top=1.8)
plt.show()

X_test = []
y_test = []

for batch in test_loader:
    images, labels = batch
    X_test.append(images.numpy())  # Convert TensorFlow tensor to NumPy array
    y_test.append(labels.numpy())  # Convert TensorFlow tensor to NumPy array

# Concatenate the batches into a single array
X_test = np.concatenate(X_test, axis=0)
y_test = np.concatenate(y_test, axis=0)

# Convert y_test to categorical labels
y_test_categorical = tf.keras.utils.to_categorical(y_test, num_classes=n_classes)

X_train = []
y_train = []

for batch in train_loader:
    images, labels = batch
    X_train.append(images.numpy())  # Convert TensorFlow tensor to NumPy array
    y_train.append(labels.numpy())  # Convert TensorFlow tensor to NumPy array

# Concatenate the batches into a single array
X_train = np.concatenate(X_train, axis=0)
y_train = np.concatenate(y_train, axis=0)

# Convert y_train to categorical labels
y_train_categorical = tf.keras.utils.to_categorical(y_train, num_classes=n_classes)
# Out:
# {'python_class': 'BloodMNIST', 'description': 'The BloodMNIST is based on a dataset of individual normal cells, captured from individuals without infection, hematologic or oncologic disease and free of any pharmacologic treatment at the moment of blood collection. It contains a total of 17,092 images and is organized into 8 classes. We split the source dataset with a ratio of 7:1:2 into training, validation and test set. The source images with resolution 3×360×363 pixels are center-cropped into 3×200×200, and then resized into 3×28×28.', 'url': 'https://zenodo.org/records/10519652/files/bloodmnist.npz?download=1', 'MD5': '7053d0359d879ad8a5505303e11de1dc', 'url_64': 'https://zenodo.org/records/10519652/files/bloodmnist_64.npz?download=1', 'MD5_64': '2b94928a2ae4916078ca51e05b6b800b', 'url_128': 'https://zenodo.org/records/10519652/files/bloodmnist_128.npz?download=1', 'MD5_128': 'adace1e0ed228fccda1f39692059dd4c', 'url_224': 'https://zenodo.org/records/10519652/files/bloodmnist_224.npz?download=1', 'MD5_224': 'b718ff6835fcbdb22ba9eacccd7b2601', 'task': 'multi-class', 'label': {'0': 'basophil', '1': 'eosinophil', '2': 'erythroblast', '3': 'immature granulocytes(myelocytes, metamyelocytes and promyelocytes)', '4': 'lymphocyte', '5': 'monocyte', '6': 'neutrophil', '7': 'platelet'}, 'n_channels': 3, 'n_samples': {'train': 11959, 'val': 1712, 'test': 3421}, 'license': 'CC BY 4.0'}
# Using downloaded and verified file: /home/jix033/.medmnist/bloodmnist.npz
# Using downloaded and verified file: /home/jix033/.medmnist/bloodmnist.npz
# Using downloaded and verified file: /home/jix033/.medmnist/bloodmnist.npz
# Train samples: 11959, Validation samples: 1712, Test samples: 3421
# basophil: 852
# eosinophil: 2181
# erythroblast: 1085
# immature granulocytes(myelocytes, metamyelocytes and promyelocytes): 2026
# lymphocyte: 849
# monocyte: 993
# neutrophil: 2330
# platelet: 1643

# %% [markdown]
# # The DNN

# %%
def build_dnn_model(input_shape):
    model = Sequential()
    model.add(Flatten(input_shape=input_shape))  # Flatten the input
    model.add(Dense(1024, activation='relu'))  # First fully connected layer
    model.add(Dense(128, activation='relu'))   # Second fully connected layer
    model.add(Dropout(0.25))  # Dropout layer for regularization
    model.add(Dense(8, activation='softmax'))  # Output layer with softmax activation

    return model

input_shape = (28, 28, 3)
dnn_model = build_dnn_model(input_shape)

dnn_model.summary()

plot_model(dnn_model, to_file='dnn_model.png', show_shapes=True)
#set environment for clearML
# %env CLEARML_WEB_HOST=https://app.clear.ml
# %env CLEARML_API_HOST=https://api.clear.ml
# %env CLEARML_FILES_HOST=https://files.clear.ml
# %env CLEARML_API_ACCESS_KEY=UM467TGFU1L1ICCP9LHV
# %env CLEARML_API_SECRET_KEY=eBhwfcZCImDq6FZSTDByWrfCAMLsKA5D0ZzUfUuW9i2uYFMkPJ

train_number = 1 
task = Task.init(project_name="BloodMNIST-Group6", task_name=f"DNN training {train_number}")
learning_rate = 0.001
dnn_model.compile(optimizer=Adam(learning_rate), 
                  loss=CategoricalCrossentropy(), 
                  metrics=['accuracy'])

# Update hyperparameters to ClearML
params = {
    "number_of_epochs": 50,
    "batch_size": batch_size,
    "base_lr": learning_rate,
    "decrease_lr": "by 10 every 30 epochs",
    "loss_func": "CategoricalCrossentropy",
    "optimizer": "Adam"
}
params = task.connect(params)

# Upload model to ClearML
output_model = OutputModel(task=task)
output_model.update_labels(cml_labels)
output_model.update_design(config_dict=dnn_model.get_config())

# Callbacks for ClearML
class ClearMLCallback(Callback):
    def on_epoch_end(self, epoch, logs=None):
        Logger.current_logger().report_scalar("Loss", "training loss", iteration=epoch, value=logs["loss"])
        Logger.current_logger().report_scalar("Accuracy", "training accuracy", iteration=epoch, value=logs["accuracy"])
        Logger.current_logger().report_scalar("Loss", "val loss", iteration=epoch, value=logs["val_loss"])
        Logger.current_logger().report_scalar("Accuracy", "val accuracy", iteration=epoch, value=logs["val_accuracy"])

checkpoint = ModelCheckpoint(filepath='model_{epoch}.h5', save_best_only=True, monitor='val_loss', mode='min')

# Training the model
history = dnn_model.fit(train_loader, 
                        epochs=50, 
                        validation_data=val_loader, 
                        callbacks=[ClearMLCallback(), checkpoint])

# Evaluate the model
test_loss, test_accuracy = dnn_model.evaluate(test_loader)
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}')

# Close ClearML task
task.close()

print('Finished Training')
dnn_model.save('DNN_model.h5')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 2352)              0
#
#  dense_6 (Dense)             (None, 1024)              2409472
#
#  dense_7 (Dense)             (None, 128)               131200
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 8)                 1032
#
# =================================================================
# Total params: 2541704 (9.70 MB)
# Trainable params: 2541704 (9.70 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# env: CLEARML_WEB_HOST=https://app.clear.ml
# env: CLEARML_API_HOST=https://api.clear.ml
# env: CLEARML_FILES_HOST=https://files.clear.ml
# env: CLEARML_API_ACCESS_KEY=UM467TGFU1L1ICCP9LHV
# env: CLEARML_API_SECRET_KEY=eBhwfcZCImDq6FZSTDByWrfCAMLsKA5D0ZzUfUuW9i2uYFMkPJ
# ClearML Task: created new task id=3ad06a2fbf644380b9f48844e6c1d4cb
# ClearML results page: https://app.clear.ml/projects/b7e1b6a8e7ea4cac83038d4e2dee6907/experiments/3ad06a2fbf644380b9f48844e6c1d4cb/output/log
# Epoch 1/50
# 5/6 [========================>.....] - ETA: 0s - loss: 2.8864 - accuracy: 0.2111
# /home/jix033/.local/lib/python3.9/site-packages/clearml/binding/frameworks/tensorflow_bind.py:1918: UserWarning:
#
# You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
# 6/6 [==============================] - 7s 922ms/step - loss: 2.8094 - accuracy: 0.2173 - val_loss: 1.7052 - val_accuracy: 0.3826
# Epoch 2/50
# 6/6 [==============================] - 5s 855ms/step - loss: 1.6996 - accuracy: 0.4053 - val_loss: 1.2701 - val_accuracy: 0.5993
# Epoch 3/50
# 6/6 [==============================] - 5s 856ms/step - loss: 1.3170 - accuracy: 0.5046 - val_loss: 1.0425 - val_accuracy: 0.6606
# Epoch 4/50
# 6/6 [==============================] - 5s 850ms/step - loss: 1.1158 - accuracy: 0.5904 - val_loss: 0.9034 - val_accuracy: 0.6857
# Epoch 5/50
# 6/6 [==============================] - 5s 839ms/step - loss: 0.9998 - accuracy: 0.6388 - val_loss: 0.8265 - val_accuracy: 0.7091
# Epoch 6/50
# 6/6 [==============================] - 5s 834ms/step - loss: 0.9029 - accuracy: 0.6802 - val_loss: 0.7593 - val_accuracy: 0.7301
# Epoch 7/50
# 6/6 [==============================] - 5s 833ms/step - loss: 0.8474 - accuracy: 0.6990 - val_loss: 0.7197 - val_accuracy: 0.7331
# Epoch 8/50
# 6/6 [==============================] - 5s 869ms/step - loss: 0.8041 - accuracy: 0.7144 - val_loss: 0.6961 - val_accuracy: 0.7605
# Epoch 9/50
# 6/6 [==============================] - 5s 828ms/step - loss: 0.7791 - accuracy: 0.7209 - val_loss: 0.6583 - val_accuracy: 0.7775
# Epoch 10/50
# 6/6 [==============================] - 5s 835ms/step - loss: 0.7415 - accuracy: 0.7377 - val_loss: 0.6453 - val_accuracy: 0.7780
# Epoch 11/50
# 6/6 [==============================] - 5s 851ms/step - loss: 0.7108 - accuracy: 0.7531 - val_loss: 0.6165 - val_accuracy: 0.7821
# Epoch 12/50
# 6/6 [==============================] - 5s 852ms/step - loss: 0.6846 - accuracy: 0.7591 - val_loss: 0.5940 - val_accuracy: 0.7868
# Epoch 13/50
# 6/6 [==============================] - 5s 886ms/step - loss: 0.6613 - accuracy: 0.7706 - val_loss: 0.5781 - val_accuracy: 0.7932
# Epoch 14/50
# 6/6 [==============================] - 5s 829ms/step - loss: 0.6354 - accuracy: 0.7841 - val_loss: 0.5587 - val_accuracy: 0.8002
# Epoch 15/50
# 6/6 [==============================] - 5s 850ms/step - loss: 0.6234 - accuracy: 0.7843 - val_loss: 0.5487 - val_accuracy: 0.8043
# Epoch 16/50
# 6/6 [==============================] - 5s 830ms/step - loss: 0.6030 - accuracy: 0.7927 - val_loss: 0.5380 - val_accuracy: 0.8055
# Epoch 17/50
# 6/6 [==============================] - 5s 905ms/step - loss: 0.5894 - accuracy: 0.7991 - val_loss: 0.5304 - val_accuracy: 0.8102
# Epoch 18/50
# 6/6 [==============================] - 5s 835ms/step - loss: 0.5657 - accuracy: 0.8050 - val_loss: 0.5133 - val_accuracy: 0.8166
# Epoch 19/50
# 6/6 [==============================] - 5s 840ms/step - loss: 0.5484 - accuracy: 0.8103 - val_loss: 0.5066 - val_accuracy: 0.8218
# Epoch 20/50
# 4/6 [===================>..........] - ETA: 0s - loss: 0.5375 - accuracy: 0.8152
# /home/jix033/.local/lib/python3.9/site-packages/clearml/binding/frameworks/tensorflow_bind.py:1918: UserWarning:
#
# You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
# 6/6 [==============================] - 5s 889ms/step - loss: 0.5347 - accuracy: 0.8163 - val_loss: 0.4946 - val_accuracy: 0.8248
# Epoch 21/50
# 6/6 [==============================] - 5s 843ms/step - loss: 0.5307 - accuracy: 0.8162 - val_loss: 0.4851 - val_accuracy: 0.8318
# Epoch 22/50
# 6/6 [==============================] - 1s 46ms/step - loss: 0.5080 - accuracy: 0.8247 - val_loss: 0.4894 - val_accuracy: 0.8178
# Epoch 23/50
# 6/6 [==============================] - 5s 864ms/step - loss: 0.5050 - accuracy: 0.8236 - val_loss: 0.4711 - val_accuracy: 0.8259
# Epoch 24/50
# 6/6 [==============================] - 5s 834ms/step - loss: 0.4974 - accuracy: 0.8257 - val_loss: 0.4658 - val_accuracy: 0.8411
# Epoch 25/50
# 6/6 [==============================] - 5s 898ms/step - loss: 0.4771 - accuracy: 0.8339 - val_loss: 0.4552 - val_accuracy: 0.8394
# Epoch 26/50
# 6/6 [==============================] - 5s 843ms/step - loss: 0.4592 - accuracy: 0.8418 - val_loss: 0.4531 - val_accuracy: 0.8446
# Epoch 27/50
# 6/6 [==============================] - 5s 847ms/step - loss: 0.4585 - accuracy: 0.8368 - val_loss: 0.4394 - val_accuracy: 0.8446
# Epoch 28/50
# 6/6 [==============================] - 5s 846ms/step - loss: 0.4485 - accuracy: 0.8429 - val_loss: 0.4371 - val_accuracy: 0.8400
# Epoch 29/50
# 6/6 [==============================] - 1s 45ms/step - loss: 0.4386 - accuracy: 0.8472 - val_loss: 0.4373 - val_accuracy: 0.8423
# Epoch 30/50
# 6/6 [==============================] - 5s 850ms/step - loss: 0.4268 - accuracy: 0.8508 - val_loss: 0.4242 - val_accuracy: 0.8475
# Epoch 31/50
# 6/6 [==============================] - 5s 845ms/step - loss: 0.4155 - accuracy: 0.8541 - val_loss: 0.4180 - val_accuracy: 0.8505
# Epoch 32/50
# 6/6 [==============================] - 5s 897ms/step - loss: 0.4104 - accuracy: 0.8572 - val_loss: 0.4098 - val_accuracy: 0.8528
# Epoch 33/50
# 6/6 [==============================] - 1s 43ms/step - loss: 0.3947 - accuracy: 0.8620 - val_loss: 0.4112 - val_accuracy: 0.8511
# Epoch 34/50
# 6/6 [==============================] - 5s 840ms/step - loss: 0.3996 - accuracy: 0.8601 - val_loss: 0.4062 - val_accuracy: 0.8528
# Epoch 35/50
# 6/6 [==============================] - 1s 57ms/step - loss: 0.3930 - accuracy: 0.8617 - val_loss: 0.4121 - val_accuracy: 0.8475
# Epoch 36/50
# 6/6 [==============================] - 5s 840ms/step - loss: 0.3862 - accuracy: 0.8667 - val_loss: 0.3985 - val_accuracy: 0.8575
# Epoch 37/50
# 6/6 [==============================] - 5s 826ms/step - loss: 0.3762 - accuracy: 0.8682 - val_loss: 0.3949 - val_accuracy: 0.8610
# Epoch 38/50
# 6/6 [==============================] - 4s 724ms/step - loss: 0.3685 - accuracy: 0.8728 - val_loss: 0.3919 - val_accuracy: 0.8581
# Epoch 39/50
# 6/6 [==============================] - 1s 45ms/step - loss: 0.3620 - accuracy: 0.8737 - val_loss: 0.4015 - val_accuracy: 0.8616
# Epoch 40/50
# 6/6 [==============================] - 5s 873ms/step - loss: 0.3487 - accuracy: 0.8793 - val_loss: 0.3887 - val_accuracy: 0.8616
# Epoch 41/50
# 6/6 [==============================] - 5s 915ms/step - loss: 0.3469 - accuracy: 0.8780 - val_loss: 0.3881 - val_accuracy: 0.8604
# Epoch 42/50
# 6/6 [==============================] - 5s 844ms/step - loss: 0.3408 - accuracy: 0.8823 - val_loss: 0.3843 - val_accuracy: 0.8621
# Epoch 43/50
# 6/6 [==============================] - 5s 906ms/step - loss: 0.3323 - accuracy: 0.8857 - val_loss: 0.3811 - val_accuracy: 0.8616
# Epoch 44/50
# 6/6 [==============================] - 1s 44ms/step - loss: 0.3297 - accuracy: 0.8864 - val_loss: 0.3860 - val_accuracy: 0.8592
# Epoch 45/50
# 6/6 [==============================] - 1s 60ms/step - loss: 0.3400 - accuracy: 0.8780 - val_loss: 0.4117 - val_accuracy: 0.8557
# Epoch 46/50
# 6/6 [==============================] - 1s 39ms/step - loss: 0.3417 - accuracy: 0.8825 - val_loss: 0.4115 - val_accuracy: 0.8516
# Epoch 47/50
# 6/6 [==============================] - 1s 85ms/step - loss: 0.3230 - accuracy: 0.8905 - val_loss: 0.3867 - val_accuracy: 0.8662
# Epoch 48/50
# 6/6 [==============================] - 5s 893ms/step - loss: 0.3115 - accuracy: 0.8943 - val_loss: 0.3754 - val_accuracy: 0.8674
# Epoch 49/50
# 6/6 [==============================] - 5s 901ms/step - loss: 0.3061 - accuracy: 0.8926 - val_loss: 0.3712 - val_accuracy: 0.8621
# Epoch 50/50
# 6/6 [==============================] - 4s 749ms/step - loss: 0.2958 - accuracy: 0.8966 - val_loss: 0.3646 - val_accuracy: 0.8697
# 2/2 [==============================] - 0s 23ms/step - loss: 0.3923 - accuracy: 0.8614
# Test Loss: 0.3923, Test Accuracy: 0.8614
# Finished Training
# /home/jix033/.local/lib/python3.9/site-packages/clearml/binding/frameworks/tensorflow_bind.py:1918: UserWarning:
#
# You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.

# %% [markdown]
# ## Plotting the Learning Curves for DNN Model

# %%
import matplotlib.pyplot as plt

# Access the history from the training session
loss = history.history['loss']
val_loss = history.history['val_loss']
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
epochs = range(1, len(loss) + 1)

fig, axes = plt.subplots(2, 1, figsize=(6, 6))

# Plot Training and Validation Loss
axes[0].plot(epochs, loss, 'bo-', label='Training Loss')
axes[0].plot(epochs, val_loss, 'ro-', label='Validation Loss')
axes[0].set_title('Training and Validation Loss')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Loss')
axes[0].legend()

# Plot Training and Validation Accuracy
axes[1].plot(epochs, accuracy, 'bo-', label='Training Accuracy')
axes[1].plot(epochs, val_accuracy, 'ro-', label='Validation Accuracy')
axes[1].set_title('Training and Validation Accuracy')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Accuracy')
axes[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Plotting the ROC curve for DNN model

# %%
# Make predictions
y_pred_prob = dnn_model.predict(X_test)

# Binarize the true labels in a one-vs-all fashion for ROC computation
y_test_binarized = label_binarize(y_test, classes=range(n_classes))

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_binarized[:, i], y_pred_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test_binarized.ravel(), y_pred_prob.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Compute macro-average ROC curve and ROC area
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

# Average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
cell_types = [info['label'][str(i)] for i in range(n_classes)]
colors = ['aqua', 'darkorange', 'cornflowerblue', 'darkgreen', 'red', 'purple', 'brown', 'pink']

# Plot all ROC curves
plt.figure(figsize=(10, 8))

plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

for i, (cell_type, color) in enumerate(zip(cell_types, colors)):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label='ROC curve of {0} (area = {1:0.2f})'
                   ''.format(cell_type, roc_auc[i]))

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curves - for DNN model')
plt.legend(loc="lower right")
plt.tight_layout()
plt.savefig("roc_curves.pdf")
plt.show()
# Out:
# 107/107 [==============================] - 0s 1ms/step

# %% [markdown]
# ## Plotting the F1 Scores for DNN Model

# %%
from sklearn.metrics import f1_score

# Make predictions on the test set
y_pred = dnn_model.predict(test_loader)
y_pred_labels = np.argmax(y_pred, axis=1)

# Convert true labels to binary format
y_true_labels = np.argmax(y_test, axis=1)

# Calculate F1 score for each class
f1_scores = f1_score(y_true_labels, y_pred_labels, average=None)

cell_types = [info['label'][str(i)] for i in range(n_classes)]

# Plot F1 scores
plt.figure(figsize=(8, 9))
bars = plt.bar(range(n_classes), f1_scores, color='skyblue')

# Annotate bars with F1 score values
for bar, score in zip(bars, f1_scores):
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval, f'{score:.2f}', ha='center', va='bottom')
    
plt.xlabel('Class')
plt.ylabel('F1 Score')
plt.title('F1 Score for Each Class')
plt.xticks(range(n_classes), cell_types, rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# 2/2 [==============================] - 0s 9ms/step

# %% [markdown]
# ## Plotting the Confusion Matrix for DNN Model

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Make predictions on the test data
y_pred = dnn_model.predict(X_test)

# Convert predictions and true labels to class indices
y_pred_class = np.argmax(y_pred, axis=1)
y_true_class = np.argmax(y_test, axis=1)

# Compute confusion matrix
conf_matrix = confusion_matrix(y_true_class, y_pred_class)

# Normalize the confusion matrix by the number of samples in each class
conf_matrix_normalized = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# Create annotations with both percentage and count
labels = np.array([[f"{value}\n{percentage:.2%}" for value, percentage in zip(row, row_normalized)] 
                   for row, row_normalized in zip(conf_matrix, conf_matrix_normalized)])

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix_normalized, annot=labels, fmt='', cmap='Blues', cbar=False, annot_kws={"size": 12})
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix - DNN Model')
plt.xticks(np.arange(n_classes) + 0.5, labels=classes, rotation=45, ha='right')
plt.yticks(np.arange(n_classes) + 0.5, labels=classes, rotation=0, va='center')
plt.tight_layout()
plt.show()
# Out:
# 107/107 [==============================] - 0s 2ms/step

# %% [markdown]
# # CNN

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Flatten
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from medmnist import INFO, Evaluator
from medmnist.info import INFO
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, Dense, Flatten, Reshape, Input, LeakyReLU, MaxPooling2D, UpSampling2D
from tensorflow.keras.optimizers import Adam
import tensorflow as tf

from tensorflow.keras.layers import Dropout
from tensorflow.keras.regularizers import l2


data_flag = 'bloodmnist'
info = INFO[data_flag]
n_channels = info['n_channels']
classes = info['label']
n_classes = len(info['label'])
DataClass = getattr(medmnist, info['python_class'])

# Load data
train_dataset = DataClass(split='train', download=True)
val_dataset = DataClass(split='val', download=True)
test_dataset = DataClass(split='test', download=True)

######################################try the data
# Extract X_test and y_test from the dataset
X_test = np.stack([np.array(data[0]) for data in test_dataset])
y_test = np.array([data[1] for data in test_dataset])

# Normalize and preprocess X_test
X_test = X_test.astype('float32') / 255.0  # Normalize pixel values to [0, 1]
X_test = (X_test - 0.5) / 0.5  # Further scale to [-1, 1]

# Convert y_test to one-hot encoded labels
y_test = tf.keras.utils.to_categorical(y_test, num_classes=n_classes)

print(f"Shape of X_test: {X_test.shape}")
print(f"Shape of y_test: {y_test.shape}")

######################################end

# Define the input and convolutional layers of the model
inputs = Input(shape=(28, 28, n_channels))
conv1 = Conv2D(32, (3, 3), activation='relu')(inputs)
pool1 = MaxPooling2D((2, 2))(conv1)
drop1 = Dropout(0.25)(pool1)  # Add dropout layer

conv2 = Conv2D(64, (3, 3), activation='relu')(drop1)
pool2 = MaxPooling2D((2, 2))(conv2)
drop2 = Dropout(0.25)(pool2)  # Add dropout layer

flattened = Flatten()(drop2)
hidden = Dense(128, activation='relu', kernel_regularizer=l2(0.001))(flattened)  # Add L2 regularization
drop3 = Dropout(0.5)(hidden)  # Add dropout layer

outputs = Dense(n_classes, activation='softmax')(drop3)  # Using softmax for multi-class classification
# Out:
# Using downloaded and verified file: /home/jix033/.medmnist/bloodmnist.npz
# Using downloaded and verified file: /home/jix033/.medmnist/bloodmnist.npz
# Using downloaded and verified file: /home/jix033/.medmnist/bloodmnist.npz
# Shape of X_test: (3421, 28, 28, 3)
# Shape of y_test: (3421, 8)

# %% [markdown]
# # run either optimizer and then run the predict

# %% [markdown]
# # The SGD optimizer for CNN model

# %%
# Create the model
cnn_model = Model(inputs=inputs, outputs=outputs)

# Compile the model with SGD optimizer and categorical cross-entropy loss
cnn_model.compile(optimizer=SGD(learning_rate=0.01, momentum=0.9), loss='categorical_crossentropy', metrics=['accuracy'])

# Fit the model on the training data
history = cnn_model.fit(X_train, y_train, epochs=50, batch_size=128, validation_split=0.1)

cnn_model.summary()
# Out:
# Epoch 1/50
# 2024-06-10 06:46:09.499480: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_10/dropout_15/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 85/85 [==============================] - 2s 9ms/step - loss: 1.8455 - accuracy: 0.3832 - val_loss: 1.3708 - val_accuracy: 0.6137
# Epoch 2/50
# 85/85 [==============================] - 1s 7ms/step - loss: 1.2970 - accuracy: 0.6075 - val_loss: 1.0301 - val_accuracy: 0.7207
# Epoch 3/50
# 85/85 [==============================] - 1s 8ms/step - loss: 1.0331 - accuracy: 0.7030 - val_loss: 0.8675 - val_accuracy: 0.7893
# Epoch 4/50
# 85/85 [==============================] - 1s 7ms/step - loss: 0.8822 - accuracy: 0.7588 - val_loss: 0.7433 - val_accuracy: 0.8261
# Epoch 5/50
# 85/85 [==============================] - 1s 7ms/step - loss: 0.7959 - accuracy: 0.7894 - val_loss: 0.6761 - val_accuracy: 0.8453
# Epoch 6/50
# 85/85 [==============================] - 1s 7ms/step - loss: 0.7567 - accuracy: 0.8029 - val_loss: 0.6516 - val_accuracy: 0.8595
# Epoch 7/50
# 85/85 [==============================] - 1s 7ms/step - loss: 0.7087 - accuracy: 0.8151 - val_loss: 0.5907 - val_accuracy: 0.8729
# Epoch 8/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.6813 - accuracy: 0.8259 - val_loss: 0.5675 - val_accuracy: 0.8763
# Epoch 9/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.6470 - accuracy: 0.8372 - val_loss: 0.5620 - val_accuracy: 0.8704
# Epoch 10/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.6278 - accuracy: 0.8439 - val_loss: 0.5506 - val_accuracy: 0.8662
# Epoch 11/50
# 85/85 [==============================] - 1s 7ms/step - loss: 0.6116 - accuracy: 0.8453 - val_loss: 0.5315 - val_accuracy: 0.8746
# Epoch 12/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.5882 - accuracy: 0.8489 - val_loss: 0.4847 - val_accuracy: 0.8963
# Epoch 13/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.5714 - accuracy: 0.8526 - val_loss: 0.5325 - val_accuracy: 0.8746
# Epoch 14/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.5620 - accuracy: 0.8575 - val_loss: 0.4799 - val_accuracy: 0.8980
# Epoch 15/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.5332 - accuracy: 0.8669 - val_loss: 0.4568 - val_accuracy: 0.8980
# Epoch 16/50
# 85/85 [==============================] - 1s 9ms/step - loss: 0.5216 - accuracy: 0.8681 - val_loss: 0.4528 - val_accuracy: 0.8963
# Epoch 17/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.4979 - accuracy: 0.8737 - val_loss: 0.4368 - val_accuracy: 0.9030
# Epoch 18/50
# 85/85 [==============================] - 1s 9ms/step - loss: 0.4981 - accuracy: 0.8735 - val_loss: 0.4489 - val_accuracy: 0.8930
# Epoch 19/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.4812 - accuracy: 0.8783 - val_loss: 0.4442 - val_accuracy: 0.8980
# Epoch 20/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.4660 - accuracy: 0.8822 - val_loss: 0.4162 - val_accuracy: 0.9064
# Epoch 21/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.4605 - accuracy: 0.8833 - val_loss: 0.3976 - val_accuracy: 0.9139
# Epoch 22/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.4572 - accuracy: 0.8853 - val_loss: 0.4080 - val_accuracy: 0.9038
# Epoch 23/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.4532 - accuracy: 0.8840 - val_loss: 0.3907 - val_accuracy: 0.9064
# Epoch 24/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.4374 - accuracy: 0.8893 - val_loss: 0.3901 - val_accuracy: 0.9114
# Epoch 25/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.4219 - accuracy: 0.8943 - val_loss: 0.3679 - val_accuracy: 0.9264
# Epoch 26/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.4120 - accuracy: 0.8927 - val_loss: 0.3739 - val_accuracy: 0.9147
# Epoch 27/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.4113 - accuracy: 0.8983 - val_loss: 0.3544 - val_accuracy: 0.9189
# Epoch 28/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.3938 - accuracy: 0.8991 - val_loss: 0.3668 - val_accuracy: 0.9055
# Epoch 29/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.3934 - accuracy: 0.9016 - val_loss: 0.3524 - val_accuracy: 0.9197
# Epoch 30/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.3769 - accuracy: 0.9063 - val_loss: 0.3357 - val_accuracy: 0.9273
# Epoch 31/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.3766 - accuracy: 0.9057 - val_loss: 0.3661 - val_accuracy: 0.9097
# Epoch 32/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.3809 - accuracy: 0.9005 - val_loss: 0.3459 - val_accuracy: 0.9130
# Epoch 33/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.3637 - accuracy: 0.9071 - val_loss: 0.3379 - val_accuracy: 0.9264
# Epoch 34/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.3746 - accuracy: 0.8997 - val_loss: 0.3269 - val_accuracy: 0.9264
# Epoch 35/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.3579 - accuracy: 0.9102 - val_loss: 0.3087 - val_accuracy: 0.9298
# Epoch 36/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.3531 - accuracy: 0.9093 - val_loss: 0.3402 - val_accuracy: 0.9156
# Epoch 37/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.3429 - accuracy: 0.9128 - val_loss: 0.3053 - val_accuracy: 0.9314
# Epoch 38/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.3276 - accuracy: 0.9168 - val_loss: 0.3149 - val_accuracy: 0.9247
# Epoch 39/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.3197 - accuracy: 0.9181 - val_loss: 0.3100 - val_accuracy: 0.9298
# Epoch 40/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.3215 - accuracy: 0.9167 - val_loss: 0.3079 - val_accuracy: 0.9331
# Epoch 41/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.3247 - accuracy: 0.9147 - val_loss: 0.2880 - val_accuracy: 0.9323
# Epoch 42/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.3157 - accuracy: 0.9208 - val_loss: 0.2886 - val_accuracy: 0.9289
# Epoch 43/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.3053 - accuracy: 0.9224 - val_loss: 0.2879 - val_accuracy: 0.9256
# Epoch 44/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.3026 - accuracy: 0.9245 - val_loss: 0.2959 - val_accuracy: 0.9264
# Epoch 45/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.2988 - accuracy: 0.9231 - val_loss: 0.2818 - val_accuracy: 0.9306
# Epoch 46/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.2945 - accuracy: 0.9241 - val_loss: 0.2812 - val_accuracy: 0.9348
# Epoch 47/50
# 85/85 [==============================] - 1s 9ms/step - loss: 0.2927 - accuracy: 0.9238 - val_loss: 0.2858 - val_accuracy: 0.9281
# Epoch 48/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.2863 - accuracy: 0.9269 - val_loss: 0.2827 - val_accuracy: 0.9348
# Epoch 49/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.2787 - accuracy: 0.9301 - val_loss: 0.2654 - val_accuracy: 0.9398
# Epoch 50/50
# 85/85 [==============================] - 1s 7ms/step - loss: 0.2683 - accuracy: 0.9332 - val_loss: 0.2764 - val_accuracy: 0.9306
# Model: "model_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 28, 28, 3)]       0
#
#  conv2d_8 (Conv2D)           (None, 26, 26, 32)        896
#
#  max_pooling2d_8 (MaxPoolin  (None, 13, 13, 32)        0
#  g2D)
#
#  dropout_15 (Dropout)        (None, 13, 13, 32)        0
#
#  conv2d_9 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_9 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  dropout_16 (Dropout)        (None, 5, 5, 64)          0
#
#  flatten_7 (Flatten)         (None, 1600)              0
#
#  dense_17 (Dense)            (None, 128)               204928
#
#  dropout_17 (Dropout)        (None, 128)               0
#
#  dense_18 (Dense)            (None, 8)                 1032
#
# =================================================================
# Total params: 225352 (880.28 KB)
# Trainable params: 225352 (880.28 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # The Adam optimizer for CNN model

# %%
# Create the model
cnn_model = Model(inputs=inputs, outputs=outputs)

# Compile the model with SGD optimizer and categorical cross-entropy loss
cnn_model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# Fit the model on the training data
history =cnn_model.fit(X_train, y_train, epochs=50, batch_size=128, validation_split=0.1)

# Print the model summary to verify the structure
cnn_model.summary()
# Out:
# Epoch 1/50
# 2024-06-10 06:44:23.775083: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_8/dropout_9/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 85/85 [==============================] - 3s 11ms/step - loss: 0.2048 - accuracy: 0.9528 - val_loss: 0.2338 - val_accuracy: 0.9431
# Epoch 2/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.1900 - accuracy: 0.9586 - val_loss: 0.2420 - val_accuracy: 0.9490
# Epoch 3/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.1992 - accuracy: 0.9560 - val_loss: 0.2267 - val_accuracy: 0.9473
# Epoch 4/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.1966 - accuracy: 0.9581 - val_loss: 0.2491 - val_accuracy: 0.9373
# Epoch 5/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.1916 - accuracy: 0.9597 - val_loss: 0.2356 - val_accuracy: 0.9515
# Epoch 6/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.1834 - accuracy: 0.9633 - val_loss: 0.2451 - val_accuracy: 0.9482
# Epoch 7/50
# 85/85 [==============================] - 1s 9ms/step - loss: 0.1933 - accuracy: 0.9570 - val_loss: 0.2373 - val_accuracy: 0.9465
# Epoch 8/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.1922 - accuracy: 0.9602 - val_loss: 0.2330 - val_accuracy: 0.9498
# Epoch 9/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.1961 - accuracy: 0.9568 - val_loss: 0.2465 - val_accuracy: 0.9448
# Epoch 10/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.2032 - accuracy: 0.9584 - val_loss: 0.2437 - val_accuracy: 0.9498
# Epoch 11/50
# 85/85 [==============================] - 1s 9ms/step - loss: 0.1973 - accuracy: 0.9607 - val_loss: 0.2564 - val_accuracy: 0.9406
# Epoch 12/50
# 85/85 [==============================] - 1s 9ms/step - loss: 0.1911 - accuracy: 0.9633 - val_loss: 0.2511 - val_accuracy: 0.9431
# Epoch 13/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.2015 - accuracy: 0.9595 - val_loss: 0.2334 - val_accuracy: 0.9482
# Epoch 14/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.2084 - accuracy: 0.9586 - val_loss: 0.2335 - val_accuracy: 0.9515
# Epoch 15/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.1969 - accuracy: 0.9626 - val_loss: 0.2495 - val_accuracy: 0.9440
# Epoch 16/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.1918 - accuracy: 0.9636 - val_loss: 0.2534 - val_accuracy: 0.9390
# Epoch 17/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.2000 - accuracy: 0.9610 - val_loss: 0.2388 - val_accuracy: 0.9440
# Epoch 18/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.1966 - accuracy: 0.9621 - val_loss: 0.2586 - val_accuracy: 0.9415
# Epoch 19/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.2046 - accuracy: 0.9603 - val_loss: 0.2614 - val_accuracy: 0.9423
# Epoch 20/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.1882 - accuracy: 0.9651 - val_loss: 0.2516 - val_accuracy: 0.9448
# Epoch 21/50
# 85/85 [==============================] - 1s 9ms/step - loss: 0.1986 - accuracy: 0.9607 - val_loss: 0.2440 - val_accuracy: 0.9523
# Epoch 22/50
# 85/85 [==============================] - 1s 9ms/step - loss: 0.1907 - accuracy: 0.9637 - val_loss: 0.2424 - val_accuracy: 0.9431
# Epoch 23/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.1856 - accuracy: 0.9659 - val_loss: 0.2499 - val_accuracy: 0.9390
# Epoch 24/50
# 85/85 [==============================] - 1s 9ms/step - loss: 0.1949 - accuracy: 0.9617 - val_loss: 0.2442 - val_accuracy: 0.9465
# Epoch 25/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.1889 - accuracy: 0.9641 - val_loss: 0.2475 - val_accuracy: 0.9465
# Epoch 26/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.1882 - accuracy: 0.9652 - val_loss: 0.2428 - val_accuracy: 0.9415
# Epoch 27/50
# 85/85 [==============================] - 1s 9ms/step - loss: 0.1898 - accuracy: 0.9629 - val_loss: 0.2506 - val_accuracy: 0.9448
# Epoch 28/50
# 85/85 [==============================] - 1s 9ms/step - loss: 0.1973 - accuracy: 0.9619 - val_loss: 0.2408 - val_accuracy: 0.9507
# Epoch 29/50
# 85/85 [==============================] - 1s 9ms/step - loss: 0.1934 - accuracy: 0.9657 - val_loss: 0.2482 - val_accuracy: 0.9465
# Epoch 30/50
# 85/85 [==============================] - 1s 9ms/step - loss: 0.1916 - accuracy: 0.9642 - val_loss: 0.2529 - val_accuracy: 0.9448
# Epoch 31/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.1894 - accuracy: 0.9657 - val_loss: 0.2663 - val_accuracy: 0.9431
# Epoch 32/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.1926 - accuracy: 0.9634 - val_loss: 0.2430 - val_accuracy: 0.9457
# Epoch 33/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.1847 - accuracy: 0.9680 - val_loss: 0.2357 - val_accuracy: 0.9498
# Epoch 34/50
# 85/85 [==============================] - 1s 9ms/step - loss: 0.1953 - accuracy: 0.9639 - val_loss: 0.2498 - val_accuracy: 0.9473
# Epoch 35/50
# 85/85 [==============================] - 1s 9ms/step - loss: 0.1945 - accuracy: 0.9612 - val_loss: 0.2663 - val_accuracy: 0.9398
# Epoch 36/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.1991 - accuracy: 0.9609 - val_loss: 0.2555 - val_accuracy: 0.9373
# Epoch 37/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.1813 - accuracy: 0.9677 - val_loss: 0.2618 - val_accuracy: 0.9423
# Epoch 38/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.1823 - accuracy: 0.9688 - val_loss: 0.2397 - val_accuracy: 0.9490
# Epoch 39/50
# 85/85 [==============================] - 1s 9ms/step - loss: 0.1844 - accuracy: 0.9668 - val_loss: 0.2551 - val_accuracy: 0.9415
# Epoch 40/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.1845 - accuracy: 0.9657 - val_loss: 0.2707 - val_accuracy: 0.9406
# Epoch 41/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.1839 - accuracy: 0.9672 - val_loss: 0.2671 - val_accuracy: 0.9440
# Epoch 42/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.1824 - accuracy: 0.9680 - val_loss: 0.2566 - val_accuracy: 0.9415
# Epoch 43/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.1880 - accuracy: 0.9641 - val_loss: 0.2588 - val_accuracy: 0.9406
# Epoch 44/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.1807 - accuracy: 0.9667 - val_loss: 0.2593 - val_accuracy: 0.9415
# Epoch 45/50
# 85/85 [==============================] - 1s 7ms/step - loss: 0.1812 - accuracy: 0.9677 - val_loss: 0.2460 - val_accuracy: 0.9473
# Epoch 46/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.1809 - accuracy: 0.9665 - val_loss: 0.2543 - val_accuracy: 0.9440
# Epoch 47/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.1846 - accuracy: 0.9684 - val_loss: 0.2395 - val_accuracy: 0.9457
# Epoch 48/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.1696 - accuracy: 0.9719 - val_loss: 0.2638 - val_accuracy: 0.9431
# Epoch 49/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.1770 - accuracy: 0.9677 - val_loss: 0.2598 - val_accuracy: 0.9423
# Epoch 50/50
# 85/85 [==============================] - 1s 8ms/step - loss: 0.1809 - accuracy: 0.9671 - val_loss: 0.2592 - val_accuracy: 0.9415
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 28, 28, 3)]       0
#
#  conv2d_4 (Conv2D)           (None, 26, 26, 32)        896
#
#  max_pooling2d_4 (MaxPoolin  (None, 13, 13, 32)        0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 13, 13, 32)        0
#
#  conv2d_5 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_5 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  dropout_10 (Dropout)        (None, 5, 5, 64)          0
#
#  flatten_5 (Flatten)         (None, 1600)              0
#
#  dense_13 (Dense)            (None, 128)               204928
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  dense_14 (Dense)            (None, 8)                 1032
#
# =================================================================
# Total params: 225352 (880.28 KB)
# Trainable params: 225352 (880.28 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Predict probabilities for the test set
preds_nn = cnn_model.predict(X_test)

# Binarize the labels in a one-vs-all fashion for ROC computation
y_test_binarized = label_binarize(np.argmax(y_test, axis=1), classes=range(n_classes))

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_binarized[:, i], preds_nn[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
# Out:
# 107/107 [==============================] - 0s 2ms/step

# %% [markdown]
# ## Plotting the Learning Curves for CNN Model

# %%
# Create a figure and a set of subplots
fig, axs = plt.subplots(2, 1, figsize=(6, 6))  # 1 row, 2 columns

# First subplot for loss
axs[0].plot(history.history['loss'], marker='o', linestyle='-', color='green', markersize=5, label='Train Loss')
axs[0].plot(history.history['val_loss'], marker='o', linestyle='-', color='orange', markersize=5, label='Validation Loss')
axs[0].set_title('Model Loss')
axs[0].set_ylabel('Loss')
axs[0].set_xlabel('Epoch')
axs[0].legend(loc='upper right')

# Second subplot for accuracy
axs[1].plot(history.history['accuracy'], marker='o', linestyle='-', color='green', markersize=5, label='Train Accuracy')
axs[1].plot(history.history['val_accuracy'], marker='o', linestyle='-', color='orange', markersize=5, label='Validation Accuracy')
axs[1].set_title('Training and Validation Accuracy')
axs[1].set_ylabel('Accuracy')
axs[1].set_xlabel('Epoch')
axs[1].legend(loc='lower right')


# Adjust layout
plt.tight_layout()

# Save the entire figure as a PDF file
plt.savefig("training_results.pdf")

# Show the plot
plt.show()

# %% [markdown]
# ## Plotting the ROC Curve for CNN Model

# %%
# Make predictions
y_pred_prob = cnn_model.predict(X_test)

# Binarize the labels in a one-vs-all fashion for ROC computation
y_test_binarized = label_binarize(np.argmax(y_test, axis=1), classes=range(n_classes))

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_binarized[:, i], y_pred_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test_binarized.ravel(), y_pred_prob.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Compute macro-average ROC curve and ROC area
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

# Average it and compute AUC
mean_tpr /= n_classes

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test_binarized.ravel(), y_pred_prob.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Compute macro-average ROC curve and ROC area
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

# Average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure(figsize=(10, 8))

plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

# Retrieve cell type names
cell_types = [info['label'][str(i)] for i in range(n_classes)]
colors = ['aqua', 'darkorange', 'cornflowerblue', 'darkgreen', 'red', 'purple', 'brown', 'pink']
for i, (cell_type, color) in enumerate(zip(cell_types, colors)):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label='ROC curve of {0} (area = {1:0.2f})'
                   ''.format(cell_type, roc_auc[i]))

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curves - for CNN model')
plt.legend(loc="lower right")
plt.grid(True)
plt.tight_layout()
plt.savefig("roc_curves.pdf")
plt.show()
# Out:
# 107/107 [==============================] - 0s 3ms/step

# %% [markdown]
# ## Plotting the F1 Scores for CNN Model

# %%
from sklearn.metrics import f1_score

# Make predictions on the test data
y_pred = cnn_model.predict(X_test)

# Convert predictions and true labels to class indices
y_pred_class = np.argmax(y_pred, axis=1)
y_true_class = np.argmax(y_test, axis=1)

# Compute F1 scores for each class
f1_scores = f1_score(y_true_class, y_pred_class, average=None)
cell_types = [info['label'][str(i)] for i in range(n_classes)]

# Plot F1 scores
plt.figure(figsize=(8, 9))
bars = plt.bar(range(n_classes), f1_scores, color='skyblue')

# Annotate bars with F1 score values
for bar, score in zip(bars, f1_scores):
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval, f'{score:.2f}', ha='center', va='bottom')

plt.xticks(range(n_classes), cell_types, rotation=45, ha='right')
plt.xlabel('Cell Type')
plt.ylabel('F1 Score')
plt.title('F1 Scores for CNN Model')
plt.tight_layout()
plt.show()
# Out:
# 107/107 [==============================] - 0s 2ms/step

# %% [markdown]
# ## Plotting the Confusion Matrix for CNN Model

# %%
y_pred = cnn_model.predict(X_test)

y_pred_class = np.argmax(y_pred, axis=1)
y_true_class = np.argmax(y_test, axis=1)


conf_matrix = confusion_matrix(y_true_class, y_pred_class)

# Normalize the confusion matrix by the number of samples in each class
conf_matrix_normalized = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]
labels = np.array([[f"{value}\n{percentage:.2%}" for value, percentage in zip(row, row_normalized)] 
                   for row, row_normalized in zip(conf_matrix, conf_matrix_normalized)])

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix_normalized, annot=labels, fmt='', cmap='Blues', cbar=False, annot_kws={"size": 12})
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix - CNN Model')
plt.xticks(np.arange(n_classes) + 0.5, labels=classes, rotation=45, ha='right')
plt.yticks(np.arange(n_classes) + 0.5, labels=classes, rotation=0, va='center')
plt.tight_layout()
plt.show()
# Out:
# 107/107 [==============================] - 0s 2ms/step
